# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math

from stats.utils import get_win_probability
from game.Battle import Battle
from game.Party import Party
from game.Rules import Rules
from game.State import State
from game.Team import Team
from game.Winner import Winner
from game.Mode import Mode
from players.Bot import Bot

# %%
# !g++ find_opt_policy.cpp; ./a.out 1.10 30 10000000
# Out:
# QLeft
# 0.355927, 0.387261, 0.398673, 0.405882, 0.407994, 0.411111, 0.411338, 0.411323, 0.413927, 0.413027, 0.41518, 0.414214, 0.415515, 0.412807, 0.413561, 0.41542, 0.414999, 0.414817, 0.413164, 0.411717, 0.413345, 0.414073, 0.412548, 0.412587, 0.414084, 0.412492, 0.413266, 0.413094, 0.412831, 0.412587,
# QRight
# 0.421413, 0.47822, 0.510188, 0.530142, 0.543917, 0.55569, 0.56428, 0.572962, 0.580944, 0.585289, 0.591171, 0.593588, 0.598506, 0.601459, 0.605546, 0.608054, 0.611409, 0.615187, 0.615017, 0.618693, 0.620726, 0.624377, 0.624346, 0.62531, 0.626382, 0.629388, 0.630156, 0.63229, 0.633295, 0.633067,
# trialLeft
# 325657, 330813, 331131, 332954, 332691, 334197, 333918, 333385, 333701, 333794, 335002, 333885, 334053, 334316, 333291, 334122, 335032, 332790, 334148, 334038, 334111, 333543, 333539, 333530, 335186, 333342, 333156, 332982, 334406, 333287,
# trialRight
# ...

# %%
df = pd.read_csv("results.csv")
plt.plot(df.columns[1:].astype(int), df.loc[df["Side"] == "QLeft"].iloc[0][1:], label="left")
plt.plot(df.columns[1:].astype(int), df.loc[df["Side"] == "QRight"].iloc[0][1:], label="right")
plt.xlabel("k")
plt.ylabel("p_win")
plt.legend()
plt.show();
